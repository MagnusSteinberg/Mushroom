# %% [raw]
# #1 MUSHROOMS: El siguiente dataset está relacionado al consumo de diferentes tipos de hongos. El dataset cuenta con un detalle de características por cada tipo de hongo y su clasificación como comestible, venenoso o en sin confirmar, pero se los consideran igual que los venenosos.
#
# La potencialidad del dataset consiste en poder determinar de la mejor manera nuevos hongos que puedan ser consumidos en el futuro.
#
# Como se ve más abajo cuenta con 23 columnas y 8124 filas. No hay valores nulos.

# %%
import pandas as pd
df = pd.read_csv("mushrooms.csv")
df.head()
df.shape
df.info()
df.columns
df['class'].unique()


for column in df.columns:
  print(column, df[column].unique())

df.head(5).round(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [raw]
# #2 Air_Index: es un conjunto de datos completo que proporciona un análisis en profundidad del índice de calidad del aire de ciudades de todo el mundo. Cubre el período de 2017 a 2022, indicando los niveles de contaminación del aire, lo que permite a los investigadores, políticos e interesados en el medio ambiente obtener información valiosa sobre las tendencias y variaciones de la calidad del aire en diferentes regiones.
#
# Como se ve más abajo cuenta con 21 columnas y 7323 filas. No hay valores nulos.

# %%
import pandas as pd
df = pd.read_csv("air_index.csv")
df.head()
df.shape
df.info()
df.columns
df.head(5).round(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7323 entries, 0 to 7322
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       7323 non-null   int64
#  1   Countries  7322 non-null   object
#  2   City       7323 non-null   object
#  3   2022       7323 non-null   float64
#  4   JAN        7099 non-null   float64
#  5   FEB        7153 non-null   float64
#  6   MAR        7240 non-null   float64
#  7   APR        7278 non-null   float64
#  8   MAY        7302 non-null   float64
#  9   JUN        7297 non-null   float64
#  10  JUL        7297 non-null   float64
#  11  AUG        7290 non-null   float64
#  12  SEP        7242 non-null   float64
#  13  OCT        7225 non-null   float64
#  14  NOV        7165 non-null   float64
#  15  DEC        7056 non-null   float64
#  16  2021       6462 non-null   float64
#  17  2020       3953 non-null   float64
#  18  2019       3747 non-null   float64
# ...

# %% [raw]
# #3 Life Expectancy Data: este dataset contempla los datos de los años 2000 a 2015 de todos los países. Toma en cuenta los factores de inmunización, factores de mortalidad, factores económicos, factores sociales y otros factores relacionados con la salud. Dado que las observaciones de este conjunto de datos se basan en diferentes países, será más fácil para un país determinar el factor predictivo que contribuye a un menor valor de la esperanza de vida. Esto ayudará a sugerir un país a qué área se le debe dar importancia para mejorar de manera eficiente la esperanza de vida de su población.
#
# Como se ve más abajo cuenta con 22 columnas y 2938 filas. No hay valores nulos.

# %%
import pandas as pd
df = pd.read_csv("Life Expectancy Data.csv")
df.head()
df.shape
df.info()
df.columns
df.head(5).round(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...
